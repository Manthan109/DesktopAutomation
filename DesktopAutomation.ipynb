# %%
import os

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\Manthan Gupta\AppData\Local

# %%
extensions_folders = {
#No name
    'noname' : "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Uncategorized",
#Audio
    '.aif' : "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Audio",
    '.cda' : "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Audio",
    '.mid' : "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Audio",
    '.midi' : "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Audio",
    '.mp3' : "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Audio",
    '.mpa' : "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Audio",
    '.ogg' : "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Audio",
    '.wav' : "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Audio",
    '.wma' : "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Audio",
    '.wpl' : "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Audio",
    '.m3u' : "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Audio",
#Text
    '.txt' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/TextFiles",
    '.doc' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Microsoft/Word",
    '.docx' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Microsoft/Word",
    '.odt ' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/TextFiles",
    '.pdf': "C:/Users/Manthan Gupta/Desktop/Manthan/Text/PDF",
    '.rtf': "C:/Users/Manthan Gupta/Desktop/Manthan/Text/TextFiles",
    '.tex': "C:/Users/Manthan Gupta/Desktop/Manthan/Text/TextFiles",
    '.wks ': "C:/Users/Manthan Gupta/Desktop/Manthan/Text/TextFiles",
    '.wps': "C:/Users/Manthan Gupta/Desktop/Manthan/Text/TextFiles",
    '.wpd': "C:/Users/Manthan Gupta/Desktop/Manthan/Text/TextFiles",
#Video
    '.3g2': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
    '.3gp': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
    '.avi': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
    '.flv': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
    '.h264': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
    '.m4v': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
    '.mkv': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
    '.mov': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
    '.mp4': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
    '.mpg': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
    '.mpeg': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
    '.rm': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
    '.swf': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
    '.vob': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
    '.wmv': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Video",
#Images
    '.ai': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Images",
    '.bmp': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Images",
    '.gif': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Images",
    '.ico': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Images",
    '.jpg': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Images",
    '.jpeg': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Images",
    '.png': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Images",
    '.ps': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Images",
    '.psd': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Images",
    '.svg': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Images",
    '.tif': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Images",
    '.tiff': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Images",
    '.CR2': "C:/Users/Manthan Gupta/Desktop/Manthan/Media/Images",
#Internet
    '.asp': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Internet",
    '.aspx': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Internet",
    '.cer': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Internet",
    '.cfm': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Internet",
    '.cgi': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Internet",
    '.pl': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Internet",
    '.css': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Internet",
    '.htm': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Internet",
    '.js': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Internet",
    '.jsp': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Internet",
    '.part': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Internet",
    '.php': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Internet",
    '.rss': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Internet",
    '.xhtml': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Internet",
#Compressed
    '.7z': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Compressed",
    '.arj': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Compressed",
    '.deb': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Compressed",
    '.pkg': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Compressed",
    '.rar': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Compressed",
    '.rpm': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Compressed",
    '.tar.gz': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Compressed",
    '.z': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Compressed",
    '.zip': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Compressed",
#Disc
    '.bin': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Disc",
    '.dmg': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Disc",
    '.iso': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Disc",
    '.toast': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Disc",
    '.vcd': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Disc",
#Data
    '.csv': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Database",
    '.dat': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Database",
    '.db': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Database",
    '.dbf': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Database",
    '.log': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Database",
    '.mdb': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Database",
    '.sav': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Database",
    '.sql': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Database",
    '.tar': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Database",
    '.xml': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Database",
    '.json': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Database",
#Executables
    '.apk': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Executables",
    '.bat': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Executables",
    '.com': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Executables",
    '.exe': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Executables",
    '.gadget': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Executables",
    '.jar': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Executables",
    '.wsf': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Executables",
#Fonts
    '.fnt': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Fonts",
    '.fon': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Fonts",
    '.otf': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Fonts",
    '.ttf': "C:/Users/Manthan Gupta/Desktop/Manthan/Other/Fonts",
#Presentations
    '.key': "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Presentations",
    '.odp': "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Presentations",
    '.pps': "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Presentations",
    '.ppt': "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Presentations",
    '.pptx': "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Presentations",
#Programming
    '.c': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/C&C++",
    '.class': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Java",
    '.dart': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Dart",
    '.py': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Python",
    '.sh': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Shell",
    '.swift': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/Swift",
    '.html': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/C&C++",
    '.h': "C:/Users/Manthan Gupta/Desktop/Manthan/Programming/C&C++",
#Spreadsheets
    '.ods' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Microsoft/Excel",
    '.xlr' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Microsoft/Excel",
    '.xls' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Microsoft/Excel",
    '.xlsx' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Microsoft/Excel",
#System
    '.bak' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
    '.cab' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
    '.cfg' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
    '.cpl' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
    '.cur' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
    '.dll' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
    '.dmp' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
    '.drv' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
    '.icns' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
    '.ico' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
    '.ini' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
    '.lnk' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
    '.msi' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
    '.sys' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
    '.tmp' : "C:/Users/Manthan Gupta/Desktop/Manthan/Text/Other/System",
}

# %%
import os.path 
from os import path
import shutil
directory="C:/Users/Manthan Gupta/Desktop"
files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(directory):
    for file in f:
        for extension in extensions_folders:
            if extension in file:
                files.append(os.path.join(r, file))
                if(path.exists(extensions_folders[extension])):
                    pass
                else:
                    os.mkdir(extensions_folders[extension])
                if(path.exists(directory+"/"+file)):
                    pass
                else:
                    continue
                shutil.move(directory+"/"+file,extensions_folders[extension]+"/"+file)
